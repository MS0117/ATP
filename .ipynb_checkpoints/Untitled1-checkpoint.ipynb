# %%
from vllm import LLM, SamplingParams

# 모델 이름 설정
model_name = "deepseek-ai/DeepSeek-Prover-V1.5-Base"

# vLLM을 사용하여 모델 로드
llm = LLM(model_name, dtype="float16",max_model_len=512)  # float16 사용 (메모리 절약)

# Sampling 설정
sampling_params = SamplingParams(
    temperature=0.7,  # 다양성 조절 (낮으면 보수적, 높으면 창의적)
    top_p=0.9,  # nucleus sampling
    max_tokens=256,  # 최대 생성 길이
)

# 프롬프트 입력
prompt = "Theorem: The sum of two even numbers is always even.\nProof:"

# 모델에 입력 후 생성
outputs = llm.generate(prompt, sampling_params)

# 결과 출력
for output in outputs:
    print("Generated Text:\n", output.outputs[0].text)
print("prompt",prompt)
print("outputs",output.outputs[0].text)
# Out:
# INFO 03-17 18:49:09 __init__.py:183] Automatically detected platform cuda.
# WARNING 03-17 18:49:13 config.py:2318] Casting torch.bfloat16 to torch.float16.
# INFO 03-17 18:49:19 config.py:520] This model supports multiple tasks: {'embed', 'reward', 'score', 'classify', 'generate'}. Defaulting to 'generate'.
# INFO 03-17 18:49:19 llm_engine.py:232] Initializing an LLM engine (v0.7.0) with config: model='deepseek-ai/DeepSeek-Prover-V1.5-Base', speculative_config=None, tokenizer='deepseek-ai/DeepSeek-Prover-V1.5-Base', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=deepseek-ai/DeepSeek-Prover-V1.5-Base, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=False, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 03-17 18:49:21 cuda.py:225] Using Flash Attention backend.
# INFO 03-17 18:49:22 model_runner.py:1110] Starting to load model deepseek-ai/DeepSeek-Prover-V1.5-Base...
# INFO 03-17 18:49:22 weight_utils.py:251] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 03-17 18:49:26 model_runner.py:1115] Loading model weights took 12.8726 GB
# INFO 03-17 18:49:27 worker.py:266] Memory profiling takes 1.04 seconds
# INFO 03-17 18:49:27 worker.py:266] the current vLLM instance can use total_gpu_memory (15.73GiB) x gpu_memory_utilization (0.90) = 14.16GiB
# INFO 03-17 18:49:27 worker.py:266] model weights take 12.87GiB; non_torch_memory takes 0.04GiB; PyTorch activation peak memory takes 0.95GiB; the rest of the memory reserved for KV Cache is 0.29GiB.
# INFO 03-17 18:49:27 executor_base.py:108] # CUDA blocks: 40, # CPU blocks: 546
# INFO 03-17 18:49:27 executor_base.py:113] Maximum concurrency for 1024 tokens per request: 0.62x
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       4 model_name = "deepseek-ai/DeepSeek-Prover-V1.5-Base"
#       6 # vLLM을 사용하여 모델 로드
# ----> 7 llm = LLM(model_name, dtype="float16",max_model_len=1024)  # float16 사용 (메모리 절약)
#       9 # Sampling 설정
#      10 sampling_params = SamplingParams(
#      11     temperature=0.7,  # 다양성 조절 (낮으면 보수적, 높으면 창의적)
#      12     top_p=0.9,  # nucleus sampling
#      13     max_tokens=256,  # 최대 생성 길이
#      14 )
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/utils.py:1039, in deprecate_args.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#    1032             msg += f" {additional_message}"
#    1034         warnings.warn(
#    1035             DeprecationWarning(msg),
#    1036             stacklevel=3,  # The inner function takes up one level
#    1037         )
# -> 1039 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/entrypoints/llm.py:239, in LLM.__init__(self, model, tokenizer, tokenizer_mode, skip_tokenizer_init, trust_remote_code, allowed_local_media_path, tensor_parallel_size, dtype, quantization, revision, tokenizer_revision, seed, gpu_memory_utilization, swap_space, cpu_offload_gb, enforce_eager, max_seq_len_to_capture, disable_custom_all_reduce, disable_async_output_proc, hf_overrides, mm_processor_kwargs, task, override_pooler_config, compilation_config, **kwargs)
#     236 # Logic to switch between engines is done at runtime instead of import
#     237 # to avoid import order issues
#     238 self.engine_class = self.get_engine_class()
# --> 239 self.llm_engine = self.engine_class.from_engine_args(
#     240     engine_args, usage_context=UsageContext.LLM_CLASS)
#     242 self.request_counter = Counter()
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/engine/llm_engine.py:482, in LLMEngine.from_engine_args(cls, engine_args, usage_context, stat_loggers)
#     480 executor_class = cls._get_executor_cls(engine_config)
#     481 # Create the LLM engine.
# --> 482 engine = cls(
#     483     vllm_config=engine_config,
#     484     executor_class=executor_class,
#     485     log_stats=not engine_args.disable_log_stats,
#     486     usage_context=usage_context,
#     487     stat_loggers=stat_loggers,
#     488 )
#     490 return engine
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/engine/llm_engine.py:274, in LLMEngine.__init__(self, vllm_config, executor_class, log_stats, usage_context, stat_loggers, input_registry, mm_registry, use_cached_outputs)
#     271 self.model_executor = executor_class(vllm_config=vllm_config, )
#     273 if self.model_config.runner_type != "pooling":
# --> 274     self._initialize_kv_caches()
#     276 # If usage stat is enabled, collect relevant info.
#     277 if is_usage_stats_enabled():
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/engine/llm_engine.py:427, in LLMEngine._initialize_kv_caches(self)
#     424 self.cache_config.num_gpu_blocks = num_gpu_blocks
#     425 self.cache_config.num_cpu_blocks = num_cpu_blocks
# --> 427 self.model_executor.initialize_cache(num_gpu_blocks, num_cpu_blocks)
#     428 elapsed = time.time() - start
#     429 logger.info(("init engine (profile, create kv cache, "
#     430              "warmup model) took %.2f seconds"), elapsed)
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/executor/executor_base.py:119, in ExecutorBase.initialize_cache(self, num_gpu_blocks, num_cpu_blocks)
#     116 self.cache_config.num_gpu_blocks = num_gpu_blocks
#     117 self.cache_config.num_cpu_blocks = num_cpu_blocks
# --> 119 self.collective_rpc("initialize_cache",
#     120                     args=(num_gpu_blocks, num_cpu_blocks))
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/executor/uniproc_executor.py:49, in UniProcExecutor.collective_rpc(self, method, timeout, args, kwargs)
#      47 if kwargs is None:
#      48     kwargs = {}
# ---> 49 answer = run_method(self.driver_worker, method, args, kwargs)
#      50 return [answer]
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/utils.py:2208, in run_method(obj, method, args, kwargs)
#    2206 else:
#    2207     func = partial(method, obj)  # type: ignore
# -> 2208 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/worker/worker.py:293, in Worker.initialize_cache(self, num_gpu_blocks, num_cpu_blocks)
#     287 def initialize_cache(self, num_gpu_blocks: int,
#     288                      num_cpu_blocks: int) -> None:
#     289     """Allocate GPU and CPU KV cache with the specified number of blocks.
#     290
#     291     This also warms up the model, which may record CUDA graphs.
#     292     """
# --> 293     raise_if_cache_size_invalid(num_gpu_blocks,
#     294                                 self.cache_config.block_size,
#     295                                 self.cache_config.is_attention_free,
#     296                                 self.model_config.max_model_len)
#     298     self.cache_config.num_gpu_blocks = num_gpu_blocks
#     299     self.cache_config.num_cpu_blocks = num_cpu_blocks
#
# File ~/miniconda3/envs/optimized_env/lib/python3.10/site-packages/vllm/worker/worker.py:546, in raise_if_cache_size_invalid(num_gpu_blocks, block_size, is_attention_free, max_model_len)
#     544 max_seq_len = block_size * num_gpu_blocks
#     545 if not is_attention_free and max_model_len > max_seq_len:
# --> 546     raise ValueError(
#     547         f"The model's max seq len ({max_model_len}) "
#     548         "is larger than the maximum number of tokens that can be "
#     549         f"stored in KV cache ({max_seq_len}). Try increasing "
#     550         "`gpu_memory_utilization` or decreasing `max_model_len` when "
#     551         "initializing the engine.")
#
# ValueError: The model's max seq len (1024) is larger than the maximum number of tokens that can be stored in KV cache (640). Try increasing `gpu_memory_utilization` or decreasing `max_model_len` when initializing the engine.

# %%
encoded_result=tokenizer(result,return_offsets_mapping=True,
                add_special_tokens=True)
completion_ids = encoded_result["input_ids"]

# %%
print(encoded_result)
# Out:
# {'input_ids': [100000, 2219, 5379, 1157, 481, 330, 5734, 372, 14237, 245, 5162, 285, 245, 845, 280, 2131, 12, 2834, 12016, 276, 274, 2827, 11, 1066, 254, 5162, 11, 8726, 11, 3039, 11, 285, 2827, 418, 521, 15347, 13, 429, 2827, 317, 13637, 372, 245, 24151, 2555, 280, 254, 3039, 11, 1066, 254, 4297, 12811, 276, 1319, 1437, 317, 13637, 457, 245, 24273, 1157, 280, 254, 5162, 366, 254, 5939, 2131, 13, 185, 185, 85169, 4908, 481, 330, 13429, 881, 984, 12232, 11, 3093, 12, 4912, 285, 4924, 12, 4912, 13, 17392, 12, 4912, 5379, 4908, 418, 4908, 280, 254, 5162, 285, 245, 845, 280,
ention function can be described as mapping a query and a set of key-value pairs to an output, where the query, keys, values, and output are all vectors. The output is computed as a weighted sum of the values, where the weight assigned to each value is computed by a compatibility function of the query with the corresponding key.
#
# Attention functions can be divided into two categories, content-based and location-based. Content-based attention functions are functions of the query and a set of items, where the items are vectors. Location-based attention functions are functions of the query and a set of locations, where the locations are scalars.
#
# Content-based attention functions

# %%
full_encoded = tokenizer(
            full_text,
            return_offsets_mapping=True,
            add_special_tokens=False
        )

# %%
input_ids = full_encoded["input_ids"]
offsets = full_encoded["offset_mapping"]  # list of (start, end)
print(input_ids)
# Out:
# [2219, 5379, 1157, 481, 330, 5734, 372, 14237, 245, 5162, 285, 245, 845, 280, 2131, 12, 2834, 12016, 276, 274, 2827, 11, 1066, 254, 5162, 11, 8726, 11, 3039, 11, 285, 2827, 418, 521, 15347, 13, 429, 2827, 317, 2219, 5379, 1157, 481, 330, 5734, 372, 14237, 245, 5162, 285, 245, 845, 280, 2131, 12, 2834, 12016, 276, 274, 2827, 11, 1066, 254, 5162, 11, 8726, 11, 3039, 11, 285, 2827, 418, 521, 15347, 13, 429, 2827, 317, 13637, 372, 245, 24151, 2555, 280, 254, 3039, 11, 1066, 254, 4297, 12811, 276, 1319, 1437, 317, 13637, 457, 245, 24273, 1157, 280, 254, 5162, 366, 254, 5939, 2131, 13, 185, 185, 85169, 4908, 481, 330, 13429, 881, 984, 12232, 11, 3093, 12, 4912, 285, 4924, 12, 4912, 13, 17392, 12, 4912, 5379, 4908, 418, 4908, 280, 254, 5162, 285, 245, 845, 280, 5023, 11, 1066, 254, 5023, 418, 15347, 13, 21832, 12, 4912, 5379, 4908, 418, 4908, 280, 254, 5162, 285, 245, 845, 280, 10582, 11, 1066, 254, 10582, 418, 65080, 13, 185, 185, 7255, 12, 4912, 5379, 4908]

# %%
token_scores = []
token_texts = []
prompt_len = len(text)
token_id=[]
token_id.append(input_ids[prompt_len])
for tid, (start, end) in zip(input_ids, offsets):           #character-token alignment
    # If you only want tokens fully in the completion portion,
    # check if start >= prompt_len
    # (If you want partial coverage for tokens that straddle the boundary,
    # you'd have to do a partial average or something more advanced.)
    if start >= prompt_len:

        # The raw text for this token
        token_str = full_text[start:end]
        token_scores.append(1)
        token_texts.append(token_str)
        token_id.append(tid)

# %%
token_id
# Out:
# [7255,
#  2219,
#  5379,
#  1157,
#  481,
#  330,
#  5734,
#  372,
#  14237,
#  245,
#  5162,
#  285,
#  245,
#  845,
#  280,
#  2131,
#  12,
#  2834,
#  12016,
#  276,
#  274,
#  2827,
#  11,
#  1066,
#  254,
#  5162,
#  11,
#  8726,
#  11,
#  3039,
#  11,
#  285,
#  2827,
#  418,
#  521,
#  15347,
#  13,
#  429,
#  2827,
#  317,
#  13637,
#  372,
#  245,
#  24151,
#  2555,
#  280,
#  254,
#  3039,
#  11,
#  1066,
#  254,
#  4297,
#  12811,
#  276,
#  1319,
#  1437,
#  317,
#  13637,
#  457,
#  245,
#  24273,
#  1157,
#  280,
#  254,
#  5162,
#  366,
#  254,
#  5939,
#  2131,
#  13,
#  185,
#  185,
#  85169,
#  4908,
#  481,
#  330,
#  13429,
#  881,
#  984,
#  12232,
#  11,
#  3093,
#  12,
#  4912,
#  285,
#  4924,
#  12,
#  4912,
#  13,
#  17392,
#  12,
#  4912,
#  5379,
#  4908,
#  418,
#  4908,
#  280,
#  254,
#  5162,
#  285,
#  245,
#  845,
#  280,
#  5023,
#  11,
#  1066,
#  254,
#  5023,
#  418,
#  15347,
#  13,
#  21832,
#  12,
#  4912,
#  5379,
#  4908,
#  418,
#  4908,
#  280,
#  254,
#  5162,
#  285,
#  245,
#  845,
#  280,
#  10582,
#  11,
#  1066,
#  254,
#  10582,
#  418,
#  65080,
#  13,
#  185,
#  185,
#  7255,
#  12,
#  4912,
#  5379,
#  4908]
